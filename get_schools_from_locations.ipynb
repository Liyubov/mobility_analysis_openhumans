# %% [markdown]
# ### Schools information retrieval
#
# *Author: Liubov, Lecturers without borders*
#
# Retrieve information about places around the point given location.
# Input: Coordinates, Openstreetmap. Output: list of schools, suggested to a person.
# Packages used:
#
# https://help.openstreetmap.org/questions/11004/download-a-map-and-extract-position-from-places-like-schools-hospitals-etc
#
# Algorithm for objects identification from a map:
# 1. give coordinate (lat, lon)
# 2. send api call to openstreetmap
# 3. get information about places around
#
# Alternatively if we need all the school data (~1 million of uses around the world), downloading planet file in PBF, which is only ~40 GB, and then we can filter them.
#
#
# ### Openstreetmap API
#
# Openstreetmap (OSM) data types. There are 3 main data types:
# 1. nodes (data points),
# 2. ways (collection of points), the way on the other hand is a ordered list of nodes, which could correspond to a street or the outline of a house.
# 3. relations.
# There are also different types of amenities
# amenity "bar", or "highway" as we write below.
# Example of parsing data is given in the blog https://towardsdatascience.com/loading-data-from-openstreetmap-with-python-and-the-overpass-api-513882a27fd0

# %%
import overpy
# example code to test overpy openstreetmap information retrieval

api = overpy.Overpass()

# fetch all ways and nodes
result = api.query("""
    way(50.746,7.154,50.748,7.157) ["highway"];
    (._;>;);
    out body;
    """)


for way in result.ways:
    print("Name: %s" % way.tags.get("name", "n/a"))
    print("  Highway: %s" % way.tags.get("highway", "n/a"))
    print("  Nodes:")
    for node in way.nodes:
        print("    Lat: %f, Lon: %f" % (node.lat, node.lon))
        

result_school = api.query("""
    way(50.746,7.154,55.748,70.157) ["school"];
    (._;>;);
    out body;
    """)

for way in result_school.ways:
    print("Name: %s" % way.tags.get("name", "n/a"))
    print("  School: %s" % way.tags.get("school", "n/a"))
    print("  Nodes:")
# Out:
# Name: Rhedenstraße
#   Highway: residential
#   Nodes:
#     Lat: 50.746874, Lon: 7.156307
#     Lat: 50.746598, Lon: 7.156237
#     Lat: 50.746477, Lon: 7.156199
#     Lat: 50.746360, Lon: 7.156124
#     Lat: 50.746263, Lon: 7.156023
#     Lat: 50.746194, Lon: 7.155926
#     Lat: 50.746139, Lon: 7.155843
# Name: Von-Ketteler-Straße
#   Highway: residential
#   Nodes:
#     Lat: 50.746905, Lon: 7.155786
#     Lat: 50.747222, Lon: 7.155621
# Name: Mutter-Barat-Straße
#   Highway: residential
#   Nodes:
#     Lat: 50.747989, Lon: 7.156302
#     Lat: 50.747934, Lon: 7.156229
#     Lat: 50.747695, Lon: 7.155421
#     Lat: 50.747605, Lon: 7.155159
#     Lat: 50.747241, Lon: 7.154310
#     Lat: 50.746939, Lon: 7.153634
# Name: Stegerwaldstraße
#   Highway: residential
#   Nodes:
#     Lat: 50.747853, Lon: 7.153685
#     Lat: 50.747666, Lon: 7.154022
#     Lat: 50.747673, Lon: 7.154122
#     Lat: 50.747939, Lon: 7.154603
#     Lat: 50.748182, Lon: 7.155178
#     Lat: 50.748318, Lon: 7.155590
#     Lat: 50.748362, Lon: 7.155646
# Name: Alte Schulstraße
#   Highway: residential
#   Nodes:
#     Lat: 50.747537, Lon: 7.158000
#     Lat: 50.747544, Lon: 7.157841
#     Lat: 50.747554, Lon: 7.157667
#     Lat: 50.747582, Lon: 7.157470
#     Lat: 50.747620, Lon: 7.157314
#     Lat: 50.747672, Lon: 7.157152
#     Lat: 50.747732, Lon: 7.157026
#     Lat: 50.747882, Lon: 7.156751
#     Lat: 50.748061, Lon: 7.156421
#     Lat: 50.748213, Lon: 7.156179
#     Lat: 50.748263, Lon: 7.156042
#     Lat: 50.748429, Lon: 7.155750
#     Lat: 50.748831, Lon: 7.155019
#     Lat: 50.749089, Lon: 7.154576
#     Lat: 50.749207, Lon: 7.154365
#     Lat: 50.749501, Lon: 7.153915
#     Lat: 50.749608, Lon: 7.153750
#     Lat: 50.749800, Lon: 7.153468
#     Lat: 50.749847, Lon: 7.153398
#     Lat: 50.750132, Lon: 7.152963
#     Lat: 50.750224, Lon: 7.152842
# Name: n/a
#   Highway: service
#   Nodes:
#     Lat: 50.746079, Lon: 7.154944
#     Lat: 50.745963, Lon: 7.154580
#     Lat: 50.745662, Lon: 7.154815
#     Lat: 50.745788, Lon: 7.155202
# Name: Mutter-Barat-Straße
#   Highway: footway
#   Nodes:
#     Lat: 50.748061, Lon: 7.156421
#     Lat: 50.747989, Lon: 7.156302
# Name: Von-Ketteler-Straße
#   Highway: residential
#   Nodes:
#     Lat: 50.747335, Lon: 7.152963
#     Lat: 50.746992, Lon: 7.153544
#     Lat: 50.746939, Lon: 7.153634
#     Lat: 50.746733, Lon: 7.154001
#     Lat: 50.746657, Lon: 7.154135
#     Lat: 50.746585, Lon: 7.154273
#     Lat: 50.746562, Lon: 7.154380
#     Lat: 50.746560, Lon: 7.154508
#     Lat: 50.746581, Lon: 7.154655
#     Lat: 50.746868, Lon: 7.155638
#     Lat: 50.746905, Lon: 7.155786
#     Lat: 50.746912, Lon: 7.155892
#     Lat: 50.746902, Lon: 7.156003
#     Lat: 50.746874, Lon: 7.156307
#     Lat: 50.746809, Lon: 7.156921
#     Lat: 50.746751, Lon: 7.157490
# Name: Von-Ketteler-Straße
#   Highway: service
#   Nodes:
#     Lat: 50.746562, Lon: 7.154380
#     Lat: 50.746165, Lon: 7.154428
#     Lat: 50.745963, Lon: 7.154580
#     Lat: 50.745895, Lon: 7.154570
#     Lat: 50.745810, Lon: 7.154439
# Name: n/a
#   Highway: footway
#   Nodes:
#     Lat: 50.746733, Lon: 7.154001
#     Lat: 50.746488, Lon: 7.153662
# Name: Schul-Umwelt-Zentrum Mitte - Filiale Birkenstraße - Gartenarbeitsschule Tiergarten
#   School: educational_garden
#   Nodes:
# Name: Melanchthonschule
#   School: primary
#   Nodes:
# Name: Hauptschule Coerde
#   School: secondary
#   Nodes:
# Name: Gartenarbeitsschule Tempelhof-Schöneberg
#   School: educational_garden
#   Nodes:
# Name: Grundschule Traberweg
#   School: primary
#   Nodes:
# Name: Schul-Umwelt-Zentrum Mitte - Gartenarbeitsschule Wedding
#   School: educational_garden
#   Nodes:
# Name: n/a
#   School: Gymnasium
#   Nodes:
# Name: Grundschule Hoisbüttel
#   School: primary
#   Nodes:
# Name: Humboldt-Gymnasium Radeberg
#   School: secondary
#   Nodes:
# Name: Johann-Heinrich-Pestalozzi-Schule
#   School: secondary
#   Nodes:
# Name: Vorwerk EKG
#   School: classrooms
#   Nodes:
# Name: Hauptgebäude EKG
#   School: classrooms
#   Nodes:
# Name: Marstall EKG
#   School: administration/headmaster office
#   Nodes:
# Name: Neubau EKG
#   School: classrooms
#   Nodes:
# Name: Brandenburger Schule für Blinde und Sehbehinderte
#   School: blind
#   Nodes:
# Name: Grundschule Bockenem
#   School: primary_school
#   Nodes:
# Name: Школа искусств №2
#   School: art
#   Nodes:
# Name: ДЮСШ № 7
#   School: sports
#   Nodes:
# Name: Муз. школа №1
#   School: music
#   Nodes:
# Name: Детская школа искусств
#   School: music
#   Nodes:
# Name: n/a
#   School: elementary
#   Nodes:
# Name: Maria-Sybilla-Merian-Gymnasium
#   School: secondary
#   Nodes:
# Name: Friedensschule
#   School: secondary
#   Nodes:
# Name: n/a
#   School: primary
#   Nodes:
# Name: Schule Carl-Cohn-Straße
#   School: blind
#   Nodes:
# Name: Hundeschule
#   School: dog
#   Nodes:
# Name: Gartenarbeitsschule Friedrichshain-Kreuzberg
#   School: educational_garden
#   Nodes:
# Name: Школа искусств
#   School: art
#   Nodes:
# Name: Weerth-Schule
#   School: primary
#   Nodes:
# Name: Oberschule Groitzsch
#   School: secondary
#   Nodes:
# Name: Gymnasium Petrinum
#   School: secondary
#   Nodes:
# Name: Grundschule An der Sommerseite
#   School: primary
#   Nodes:
# Name: Спортшкола
#   School: sport
#   Nodes:
# Name: Kohlkamp-Grundschule
#   School: primary
#   Nodes:
# Name: Ausbildungszentrum für Gesundheitberufe des Universitätsklinikums
#   School: vocational_school
#   Nodes:
# Name: Irisschule
#   School: blind
#   Nodes:
# Name: Gesamtschule Barmen
#   School: secondary
#   Nodes:
# Name: Regenbogenschule
#   School: primary;secondary
#   Nodes:
# Name: n/a
#   School: blind
#   Nodes:
# Name: Freiherr-vom-Stein-Gymnasium
#   School: secondary
#   Nodes:
# Name: Детская школа искусств
#   School: art
#   Nodes:
# Name: Borndalschule
#   School: primary
#   Nodes:
# Name: Ludgerischule
#   School: secondary
#   Nodes:
# Name: Johannesschule
#   School: primary
#   Nodes:
# Name: Детская, юношеская спортивная школа
#   School: sport
#   Nodes:
# Name: Ludgerusschule
#   School: primary
#   Nodes:
# Name: Fanny Hensel
#   School: music_school
#   Nodes:
# Name: Gymnasium Augustinianum
#   School: secondary
#   Nodes:
# Name: Hugo-de-Grootschool
#   School: primary
#   Nodes:
# Name: August-Heyn-Gartenarbeitsschule Neukölln
#   School: educational_garden
#   Nodes:
# Name: Johannes-Gutenberg-Realschule
#   School: secondary
#   Nodes:
# Name: Landesamt für Ausbildung, Fortbildung und Personalangelegenheiten der Polizei Nordrhein-Westfalen „Carl Severing“
#   School: vocational
#   Nodes:
# Name: Helene-Lange-Schule
#   School: secondary
#   Nodes:
# Name: n/a
#   School: elemenary
#   Nodes:
# Name: Volkshochschule Mitte
#   School: Volkshochschule
#   Nodes:
# Name: Martin-Buber-Schule
#   School: blind
#   Nodes:
# Name: Martin-Bartels-Schule
#   School: blind
#   Nodes:
# Name: Martin-Bartels-Schule
#   School: blind
#   Nodes:
# Name: Mörikeschule
#   School: primary
#   Nodes:
# Name: Grundschule Groitzsch
#   School: primary
#   Nodes:
# Name: Peter-Wust-Schule
#   School: primary
#   Nodes:
# Name: Gemeinschaftsgrundschule Overath
#   School: elementary
#   Nodes:
# Name: Friedenauer Gemeinschaftsschule
#   School: secondary
#   Nodes:
# Name: n/a
#   School: Wyższa Szkoła Kupiecka
#   Nodes:
# Name: Музыкальная школа
#   School: music
#   Nodes:
# Name: СШ №69
#   School: bus_stop
#   Nodes:
# Name: Haus Rissen
#   School: political
#   Nodes:
# Name: Hittorf-Gymnasium
#   School: secondary
#   Nodes:
# Name: Lambertischule
#   School: primary
#   Nodes:
# Name: Wartburg-Grundschule
#   School: primary
#   Nodes:
# Name: n/a
#   School: primary
#   Nodes:
# Name: Astrid-Lindgren-Schule
#   School: primary
#   Nodes:
# Name: Mosaik-Schule
#   School: primary
#   Nodes:
# Name: n/a
#   School: music
#   Nodes:
# Name: n/a
#   School: schoolyard
#   Nodes:
# Name: n/a
#   School: schoolyard
#   Nodes:
# Name: Evangelische Schule für Sozialwesen "Luise Höpfner"
#   School: Berufsfachschule für Sozialwesen
#   Nodes:
# Name: n/a
#   School: music
#   Nodes:
# Name: Städtisches Gymnasium
#   School: secondary
#   Nodes:
# Name: Annette-von-Droste-Hülshoff-Schule
#   School: Realschule
#   Nodes:
# Name: Bonhoeffergrundschule
#   School: Grundschule
#   Nodes:
# Name: Michael-Ende-Schule
#   School: Grundschule
#   Nodes:
# Name: Grundschule Somborner Straße
#   School: primary
#   Nodes:
# Name: Nelson-Mandela-Schule
#   School: secondary
#   Nodes:
# Name: Lessing-Schule
#   School: Gymnasium
#   Nodes:
# Name: Sekundarschule Comenius
#   School: disused
#   Nodes:
# Name: Ottilie-Schoenewald-Weiterbildungskolleg
#   School: Kolleg
#   Nodes:
# Name: Grundschule Fürstenau
#   School: elementary
#   Nodes:
# Name: ДЮСШ "Надежда"
#   School: sport
#   Nodes:
# Name: Детская школа искусств имени М.А. Балакирева
#   School: art
#   Nodes:
# Name: Gymnasium Paulinum
#   School: secondary
#   Nodes:
# Name: Gartenarbeitsschule Steglitz-Zehlendorf
#   School: educational_garden
#   Nodes:
# Name: Grundschule im Kleefelde
#   School: Primary
#   Nodes:
# Name: Annette-von-Droste-Hülshoff-Gymnasium
#   School: secondary
#   Nodes:
# Name: Goethe-Schule
#   School: Gymnasium
#   Nodes:
# Name: Heinrich-Böll-Gesamtschule Bochum
#   School: Gesamtschule
#   Nodes:
# Name: n/a
#   School: Turnhalle
#   Nodes:
# Name: n/a
#   School: Turnhalle
#   Nodes:
# Name: n/a
#   School: Turnhalle
#   Nodes:
# Name: n/a
#   School: Turnhalle
#   Nodes:
# Name: Музыкальная школа
#   School: music
#   Nodes:
# Name: Johann-Peter-Hebel-Grundschule
#   School: primary
#   Nodes:
# Name: LVR Förderschule für körperlich-motorische Entwicklung Wuppertal
#   School: special_needs
#   Nodes:
# Name: Schul-Umwelt-Zentrum Spandau - Gartenarbeitsschule Borkzeile
#   School: educational_garden
#   Nodes:
# Name: Adolf-Diesterweg-Grundschule
#   School: primary
#   Nodes:
# Name: Philipp-Melanchthon-Gymnasium
#   School: secondary
#   Nodes:
# Name: n/a
#   School: entrance
#   Nodes:
# Name: n/a
#   School: entrance
#   Nodes:
# Name: Evangelische Grundschule Teltow-Seehof
#   School: primary
#   Nodes:
# Name: Wilma-Rudolph-Oberschule
#   School: Oberschule
#   Nodes:
# Name: Theresienschule
#   School: primary
#   Nodes:
# Name: Детская школа искусств
#   School: art
#   Nodes:
# Name: Bruder-Klaus-Schule
#   School: primary
#   Nodes:
# Name: Overberg-Kolleg
#   School: secondary
#   Nodes:
# Name: Sekundarschule Wilmersdorf
#   School: Oberschule
#   Nodes:
# Name: Hauptgebäude
#   School: Sporthalle
#   Nodes:
# Name: Rudolf-Steiner-Schule
#   School: Waldorfschule
#   Nodes:
# Name: Peter-Wust-Schule
#   School: primary
#   Nodes:
# Name: Rodomstorschule
#   School: primary
#   Nodes:
# Name: Breitenauschule
#   School: primary
#   Nodes:
# Name: n/a
#   School: secondary
#   Nodes:
# Name: n/a
#   School: secondary
#   Nodes:
# Name: n/a
#   School: secondary
#   Nodes:
# Name: n/a
#   School: secondary
#   Nodes:
# Name: n/a
#   School: secondary
#   Nodes:
# Name: n/a
#   School: secondary
#   Nodes:
# Name: n/a
#   School: secondary
#   Nodes:
# Name: n/a
#   School: secondary
#   Nodes:
# Name: n/a
#   School: secondary
#   Nodes:
# Name: n/a
#   School: primary
#   Nodes:
# Name: n/a
#   School: special school
#   Nodes:
# Name: Grundschule Gartnisch
#   School: elementary
#   Nodes:
# Name: Grundschule Am Pechauer Platz
#   School: primary
#   Nodes:
# Name: Haus der Volkshochschule
#   School: Volkshochschule
#   Nodes:
# Name: Städtische Gesamtschule Warendorf
#   School: secondary
#   Nodes:
# Name: Weilenbrink Grundschule
#   School: Grundschule
#   Nodes:
# Name: n/a
#   School: Grundschule
#   Nodes:
# Name: Grundschule in der Vöde
#   School: Grundschule
#   Nodes:
# Name: Grundschule Trebsen
#   School: primary
#   Nodes:
# Name: Музыкальная школа
#   School: music
#   Nodes:
# Name: n/a
#   School: sailing
#   Nodes:
# Name: Schillergymnasium
#   School: secondary
#   Nodes:
# Name: Grundschule an der Pulvermühle
#   School: primary
#   Nodes:
# Name: OSZ Energietechnik I
#   School: secondary
#   Nodes:
# Name: Szkoła Podstawowa w Warcie
#   School: primary
#   Nodes:
# Name: Ingeborg-Feustel-Grundschule
#   School: primary
#   Nodes:
# Name: Adolf-Glaßbrenner-Grundschule
#   School: elementary
#   Nodes:
# Name: n/a
#   School: blind
#   Nodes:
# Name: Johann-August-Zeune-Schule für Blinde
#   School: blind
#   Nodes:
# Name: Bernd-Ryke-Grundschule
#   School: primary
#   Nodes:
# Name: Воскресная школа имени святого благоверного князя Александра Невского
#   School: religion
#   Nodes:
# Name: Helene-Lange Realschule und Grundschule Feldsieper Straße
#   School: Grundschule, Realschule
#   Nodes:
# Name: Schule am Gartenfeld
#   School: special school
#   Nodes:
# Name: Private Kant-Grundschule
#   School: Private Grundschule
#   Nodes:
# Name: ДЮСШ "Спартак"
#   School: sport
#   Nodes:
# Name: Katholische Schule Sankt Hildegard
#   School: Grund- und Hauptschule für gesundheitsgeschädigte Kinder und Jugendliche
#   Nodes:
# Name: n/a
#   School: Landwirtschaftsschule
#   Nodes:
# Name: Johannisschule
#   School: primary
#   Nodes:
# Name: ДЮСШ "Юность"
#   School: sport
#   Nodes:
# Name: ДЮСШ №2
#   School: athletics;skiing;orienteering
#   Nodes:
# Name: ДЮСШ №1
#   School: sport
#   Nodes:
# Name: Bodelschwinghschule
#   School: primary
#   Nodes:
# Name: Löwenzahn-Schule Damgarten
#   School: primary
#   Nodes:
# Name: Regionale Schule "Rudolf Harbig"
#   School: Regionale Schule
#   Nodes:
# Name: Wilhelm-Hittorf-Gymnasium
#   School: secondary
#   Nodes:
# Name: Christian-Morgenstern-Schule
#   School: secondary
#   Nodes:
# Name: Dietrich-Bonhoeffer-Schule
#   School: primary
#   Nodes:
# Name: Ludwig-Erhard-Berufskolleg
#   School: vocational
#   Nodes:
# Name: n/a
#   School: secondary
#   Nodes:
# Name: Pascal-Gymnasium
#   School: secondary
#   Nodes:
# Name: Bischöfliches Mädchengymnasium Marienschule
#   School: secondary
#   Nodes:
# Name: Astrid-Lindgren-Schule
#   School: primary
#   Nodes:
# Name: Gymnasium Sankt Mauritz
#   School: secondary
#   Nodes:
# Name: Pleisterschule
#   School: primary
#   Nodes:
# Name: Grundschule am Volkspark
#   School: Grundschule
#   Nodes:
# Name: Griechisches Gymnasium
#   School: secondary
#   Nodes:
# Name: Realschule Leimbacher Straße
#   School: secondary
#   Nodes:
# Name: n/a
#   School: yes
#   Nodes:
# Name: Gymnasium Kleine Burg
#   School: secondary
#   Nodes:
# Name: Städtische Katholische Grundschule Alarichstraße
#   School: primary
#   Nodes:
# Name: Overbergschule
#   School: primary
#   Nodes:
# Name: Grundschule Wasserstraße
#   School: primary
#   Nodes:
# Name: Offene Ganztagsgrundschule Eichenstraße
#   School: primary
#   Nodes:
# Name: Sankt-Antonius-Schule
#   School: primary
#   Nodes:
# Name: Realschule Hohenstein
#   School: secondary
#   Nodes:
# Name: Helene-Stöcker-Schule (Standort Eichenstraße)
#   School: special_education_needs
#   Nodes:
# Name: Katholische Grundschule Sankt Martin
#   School: primary
#   Nodes:
# Name: Johann-Conrad-Schlaun-Gymnasium
#   School: secondary
#   Nodes:
# Name: Erich-Klausener-Schule
#   School: secondary
#   Nodes:
# Name: Ratsgymnasium
#   School: secondary
#   Nodes:
# Name: Gottfried-von-Cappenberg-Schule
#   School: primary
#   Nodes:
# Name: Fürstin-von-Gallitzin-Realschule
#   School: secondary
#   Nodes:
# Name: Mathilde Anneke Gesamtschule
#   School: vocational
#   Nodes:
# Name: Karl-Weierstraß-Grundschule
#   School: primary
#   Nodes:
# Name: Pestalozzischule
#   School: secondary
#   Nodes:
# Name: Marienschule
#   School: primary
#   Nodes:
# Name: Perthes-Gymnasium
#   School: gymnasium
#   Nodes:
# Name: Hans-Böckler Schule
#   School: primary
#   Nodes:
# Name: Hermannschule
#   School: primary
#   Nodes:
# Name: Michael-Ende-Schule
#   School: primary
#   Nodes:
# Name: Schule am Ahnsförth
#   School: Förderschule
#   Nodes:
# Name: ДЮСШ №2
#   School: sport
#   Nodes:
# Name: Hundeschule Hundeleben
#   School: dog
#   Nodes:
# Name: Musikschule Henstedt-Ulzburg
#   School: music
#   Nodes:
# Name: Schule Jungfernkopf
#   School: primary
#   Nodes:
# Name: Grundschule Neuer Garten
#   School: primary
#   Nodes:
# Name: Martin-Luther-Schule
#   School: primary
#   Nodes:
# Name: Christian-Rauch-Schule
#   School: secondary
#   Nodes:
# Name: Kreuzschule
#   School: primary
#   Nodes:
# Name: Детская школа искуств №2
#   School: art
#   Nodes:
# Name: Goetheschule
#   School: Gy
#   Nodes:
# Name: Kopernikus-Gymnasium
#   School: secondary
#   Nodes:
# Name: Wilhelm-Busch-Grundschule
#   School: primary
#   Nodes:
# Name: Nikolaischule Wolbeck
#   School: primary
#   Nodes:
# Name: OSZ Wirtschaft Leopold-Ullstein-Schule - Abteilung I
#   School: professional_education
#   Nodes:
# Name: Aegidii-Ludgeri-Schule
#   School: primary
#   Nodes:
# Name: Bunte Schule
#   School: Grundschule
#   Nodes:
# Name: Музыкальная школа №4
#   School: music
#   Nodes:
# Name: Altes Gymnasium
#   School: secondary
#   Nodes:
# Name: Дом детского творчества
#   School: art
#   Nodes:
# Name: n/a
#   School: music
#   Nodes:
# Name: Park-Oberschule
#   School: Oberschule
#   Nodes:
# Name: Grundschule Ottbergen
#   School: primary
#   Nodes:
# Name: Michaelschule
#   School: primary
#   Nodes:
# Name: Schule am Burgteich
#   School: Mittelschule
#   Nodes:
# Name: n/a
#   School: secondary
#   Nodes:
# Name: Opticus Schule
#   School: blind
#   Nodes:
# Name: Schulen am Hufenweg
#   School: Grund- und Regionalschule
#   Nodes:
# Name: ДЮСШ Заволжье
#   School: sport
#   Nodes:
# Name: Bodelschwingh-Grundschule
#   School: primary
#   Nodes:
# Name: Mariengymnasium Warendorf
#   School: secondary
#   Nodes:
# Name: Johann-Heinrich-Schmülling-Schule
#   School: secondary
#   Nodes:
# Name: n/a
#   School: yes
#   Nodes:
# Name: Детская музыкальная школа искусств №20
#   School: music
#   Nodes:
# Name: Grundschule Laer
#   School: Grundschule
#   Nodes:
# Name: Musikschule "Johann-Friedrich-Agricola"
#   School: Music
#   Nodes:
# Name: Carl-Arnold-Kortum-Schule
#   School: Hauptschule
#   Nodes:
# Name: Alt-Schmargendorf-Grundschule
#   School: primary
#   Nodes:
# Name: Staatliche Grundschule Gößnitz
#   School: primary
#   Nodes:
# Name: Staatliche Regelschule Gößnitz
#   School: secondary
#   Nodes:
# Name: n/a
#   School: gym
#   Nodes:
# Name: Klassentrakt EKG
#   School: classrooms
#   Nodes:
# Name: Arnoldschule
#   School: Grundschule
#   Nodes:
# Name: Rudolf-Steiner-Schule
#   School: Waldorfschule
#   Nodes:
# Name: Gartenarbeitsschule Treptow-Köpenick
#   School: educational_garden
#   Nodes:
# Name: August-Hermann-Francke Grundschule
#   School: primary
#   Nodes:
# Name: n/a
#   School: entrance
#   Nodes:
# Name: Ernst-Barlach-Realschule
#   School: Realschule
#   Nodes:
# Name: Schule für Musik e.V.
#   School: music
#   Nodes:
# Name: n/a
#   School: elementary
#   Nodes:
# Name: n/a
#   School: elementary
#   Nodes:
# Name: Fichtenberg-Oberschule
#   School: Oberschule
#   Nodes:
# Name: n/a
#   School: blind
#   Nodes:
# Name: Friedrich-Gottlob-Keller-Oberschule
#   School: Grundschule;Mittelschule
#   Nodes:
# Name: школа пулевой стрельбы
#   School: shooting
#   Nodes:
# Name: Zespół nr 5 Gimnazjum i Szkoły Podstawowej
#   School: entrance
#   Nodes:
# Name: n/a
#   School: Realschule
#   Nodes:
# Name: Школа исскуств
#   School: art
#   Nodes:
# Name: LWL-Berufskolleg Soest
#   School: blind
#   Nodes:
# Name: von-Vincke-Schule Bildungszentrum für Blinde und Sehbehinderte
#   School: blind
#   Nodes:
# Name: Pauline-Schule
#   School: blind
#   Nodes:
# Name: Städt. Kath. Hauptschule
#   School: Hauptschule
#   Nodes:
# Name: Hufeland Grundschule
#   School: Grundschule
#   Nodes:
# Name: Willy-Brandt-Gesamtschule (Sek. I)
#   School: Gesamtschule
#   Nodes:
# Name: Grundschule Helsen Außenstelle Landau (Grundschule am Kump)
#   School: primary
#   Nodes:
# Name: Schule für lernbehinderte Menschen "Otto Dorn"
#   School: Förderschule
#   Nodes:
# Name: Школа искусств
#   School: art
#   Nodes:
# Name: Школа Искусств
#   School: art
#   Nodes:
# Name: Oberlin-Seminar
#   School: Schulzentrum
#   Nodes:
# Name: Oberschule Bockenem
#   School: secondary school
#   Nodes:
# Name: n/a
#   School: yes
#   Nodes:
# Name: Von-Galen-Schule
#   School: secondary
#   Nodes:
# Name: Herbert-Tschäpe Grundschule
#   School: primary
#   Nodes:
# Name: Тереньгульская детская школа искусств
#   School: art
#   Nodes:
# Name: Ludgerusschule
#   School: primary
#   Nodes:
# Name: n/a
#   School: primary
#   Nodes:
# Name: Marienschule
#   School: primary
#   Nodes:
# Name: Rzemieślnicza Branżowa Szkoła I stopnia im. Stanisława Palucha w Wałbrzychu
#   School: secondary
#   Nodes:
# Name: Dreifaltigkeitsschule
#   School: primary
#   Nodes:
# Name: Barfüßerschule
#   School: secondary
#   Nodes:
# Name: Hans-Christian-Andersen Schule
#   School: primary
#   Nodes:
# Name: Музыкальная школа
#   School: music
#   Nodes:
# Name: n/a
#   School: primary
#   Nodes:
# Name: Peter-Wust-Schule
#   School: primary
#   Nodes:
# Name: Муз. школа
#   School: music
#   Nodes:
# Name: Schillerschule
#   School: secondary
#   Nodes:
# Name: Grundschule Kinderhaus-West
#   School: primary
#   Nodes:
# Name: Grundschule Sprakel
#   School: primary
#   Nodes:
# Name: Overbergschule
#   School: primary
#   Nodes:
# Name: Gemeinschaftsgrundschule Berg Fidel
#   School: primary
#   Nodes:
# Name: Schule am Hohen Rade
#   School: Oberschule
#   Nodes:
# Name: Gartenarbeitsschule Ilse Demme Charlottenburg-Wilmersdorf
#   School: educational_garden
#   Nodes:
# Name: Grundschule
#   School: primary
#   Nodes:
# Name: Verbundschule
#   School: secondary
#   Nodes:
# Name: Max&Moritz Schule
#   School: primary
#   Nodes:
# Name: Детская художественная школа
#   School: art
#   Nodes:
# Name: Neubau Private Kant-Schule
#   School: yes
#   Nodes:
# Name: Grund- und Oberschule Altendorf
#   School: primary;secondary
#   Nodes:
# Name: Wladimir-Filatow-Schule
#   School: blind
#   Nodes:
# Name: Matthias-Claudius-Schule
#   School: primary
#   Nodes:
# Name: Kardinal-von-Galen-Grundschule
#   School: primary
#   Nodes:
# Name: n/a
#   School: primary
#   Nodes:
# Name: Grundschule im Sande
#   School: primary
#   Nodes:
# Name: Paul-Schneider-Schule
#   School: primary
#   Nodes:
# Name: Eichendorffschule
#   School: primary
#   Nodes:
# Name: Gymnasium Laurentianum
#   School: secondary
#   Nodes:
# Name: Grundschule Loevelingloh
#   School: primary
#   Nodes:
# Name: Margaretenschule
#   School: primary
#   Nodes:
# Name: Anne-Frank-Berufskolleg
#   School: secondary
#   Nodes:
# Name: Verkehrsschule Friedrichshain
#   School: Verkehrsschule
#   Nodes:
# Name: Evangelische und Katholische Grundschule Hangelar
#   School: primary
#   Nodes:
# Name: Katholische Grundschule Buisdorf
#   School: primary
#   Nodes:
# Name: Gemeinschaftsgrundschule Am Pleiser Wald
#   School: primary
#   Nodes:
# Name: Schule am Nordpark
#   School: special_needs
#   Nodes:
# Name: ДШИ им. Ф.Шуберта
#   School: music
#   Nodes:
# Name: Wolfgang-Borchert-Schule
#   School: elementary
#   Nodes:
# Name: Детская музыкальная школа №3
#   School: music
#   Nodes:
# Name: Дитяча музична школа №2
#   School: music
#   Nodes:
# Name: Geschwister-Scholl-Grundschule
#   School: primary
#   Nodes:
# Name: Annette-von-Droste-Hülshoff-Grundschule
#   School: primary
#   Nodes:
# Name: n/a
#   School: Förderschule
#   Nodes:
# Name: n/a
#   School: entrance
#   Nodes:
# Name: Augustin-Wibbelt-Gymnasium
#   School: secondary
#   Nodes:
# Name: Paul- und Charlotte Kniese-Schule
#   School: blind
#   Nodes:
# Name: Weinauschule
#   School: Grundschule;Mittelschule
#   Nodes:
# Name: Grundschule am Rüdesheimer Platz
#   School: primary
#   Nodes:
# Name: Rothenburg-Grundschule
#   School: primary
#   Nodes:
# Name: Zespół Szkół Nr 7  im. Komisji Edukacji Narodowej w Wałbrzychu
#   School: yes
#   Nodes:
# Name: Дом детского творчества
#   School: optional
#   Nodes:
# Name: Grundschule auf dem Seeberg
#   School: elementary
#   Nodes:
# Name: Josefschule
#   School: primary
#   Nodes:
# Name: Astrid-Lindgren-Schule
#   School: primary
#   Nodes:
# Name: Meyerhofschule
#   School: primary
#   Nodes:
# Name: Martinusschule
#   School: primary
#   Nodes:
# Name: Zespół Szkół Samochodowych
#   School: upper_secondary
#   Nodes:
# Name: Märkisches Gymnasium Schwelm
#   School: secondary school
#   Nodes:
# Name: Gelas Hundetraining
#   School: dog
#   Nodes:
# Name: Bühner-Bach-Schule
#   School: primary
#   Nodes:
# Name: ДЮСШ №2
#   School: sport
#   Nodes:
# Name: ДЮСШ №1
#   School: sport
#   Nodes:
# Name: Franziskusschule
#   School: special_needs
#   Nodes:
# Name: Berufskolleg Warendorf
#   School: secondary
#   Nodes:
# Name: Hildegardisschule
#   School: secondary
#   Nodes:
# Name: n/a
#   School: yes
#   Nodes:
# Name: Technischer Dienst LWL-Schulen
#   School: blind
#   Nodes:
# Name: Wilhelm-Emmanuel-von-Ketteler-Berufskolleg
#   School: secondary
#   Nodes:
# Name: Grundschule Sutthausen
#   School: elementary
#   Nodes:
# Name: n/a
#   School: yes
#   Nodes:
# Name: Schul-Umwelt-Zentrum Mitte - Filiale Seestraße
#   School: educational_garden
#   Nodes:
# Name: Verkehrsschule Friedrichshain
#   School: Verkehrsschule
#   Nodes:
# Name: n/a
#   School: primary
#   Nodes:
# Name: Verkehrsschule Steglitz
#   School: Verkehrsschule
#   Nodes:
# Name: Łącznik na poziomie I pietra
#   School: yes
#   Nodes:
# Name: Offene Ganztagsgrundschule Thorner Straße
#   School: primary
#   Nodes:
# Name: Hansa-Berufskolleg
#   School: tertiary
#   Nodes:
# Name: Albert-Schweitzer-Schule
#   School: special_education_needs
#   Nodes:
# Name: Thalia Grundschule
#   School: elementary
#   Nodes:
# Name: Mansfeldschule
#   School: Förderschule
#   Nodes:
# Name: Gartenarbeitsschule Lichtenberg
#   School: educational_garden
#   Nodes:
# Name: Schul-Umwelt-Zentrum Spandau - Gartenarbeitsschule Hakenfelde
#   School: educational_garden
#   Nodes:
# Name: Gartenarbeitsschule Pankow
#   School: educational_garden
#   Nodes:
# Name: Polizeihundverein Hameln
#   School: dog
#   Nodes:

# %% [markdown]
# ### Make calls for api for schools around lat lon in given radius
#
# API calls from OSM
#
# 1. https://wiki.openstreetmap.org/wiki/Overpass_API/Overpass_API_by_Example#Highway_around_schools_with_inappropriate_maxspeed_.28since_0.7.54.29
#
# 2. https://towardsdatascience.com/loading-data-from-openstreetmap-with-python-and-the-overpass-api-513882a27fd0
#
# 3. https://automating-gis-processes.github.io/CSC/notebooks/L3/retrieve_osm_data.html
#
#
# We will get some available open infromation about schools in certain area.

# %%
import json # requests for APIs
import requests #load Python code that allow us to work with the JSON data format and the HTTP protocol

import osmnx as ox
import matplotlib.pyplot as plt
# %matplotlib inline

# https://www.digitalocean.com/community/tutorials/how-to-use-web-apis-in-python-3
# https://automating-gis-processes.github.io/CSC/notebooks/L3/retrieve_osm_data.html


# Specify the name that is used to seach for the data
place_name = "Arbat, Moscow, Russia"# Kremlin, Arbat "Kamppi, Helsinki, Finland"


# Fetch OSM street network from the location
graph = ox.graph_from_place(place_name)
type(graph)

print('loading graph of city')

# Plot the streets
fig, ax = ox.plot_graph(graph)


# Retrieve the footprint of our location
area = ox.gdf_from_place(place_name)
print('loading places')

# Retrieve buildings from the area
#buildings = ox.footprints(place_name) #buildings_from_place(place_name)

# What types are those? if there is any information about buildings_from_place
#print(type(area))
#print(type(buildings))

# Retrieve restaurants
restaurants = ox.pois_from_place(place_name, amenities=['restaurant'])

schools = ox.pois_from_place(place_name, amenities=['school'])


# How many schools do we have in this district?
len(schools)

# Available columns and names of amenity we are searching for
schools.columns
# Out:
# loading graph of Moscow
# loading places
# Index(['access', 'addr:city', 'addr:housenumber', 'addr:street', 'amenity',
#        'barrier', 'bicycle', 'contact:email', 'contact:phone',
#        'contact:website', 'education', 'education_form:fulltime',
#        'education_form:parttime', 'education_level:primary',
#        'education_level:secondary', 'education_profile:general',
#        'education_profile:languages', 'education_profile:music',
#        'education_programme:EN', 'education_system:ru_standard',
#        'element_type', 'entrance', 'foot', 'geometry', 'historic', 'memorial',
#        'name', 'name:en', 'official_name', 'opening_hours', 'osmid',
#        'ownership', 'short_name', 'start_date', 'wheelchair', 'wikidata',
#        'wikipedia', 'building', 'building:colour', 'building:levels',
#        'fence_type', 'name:de', 'nodes', 'old_name', 'roof:material',
#        'roof:shape', 'training', 'wikipedia:ru', 'addr:street2',
#        'contact:facebook', 'type', 'ways'],
#       dtype='object')

# %% [markdown]
# ### Retrieve information about places
# Given certain coordinate we want now to get the information about places around certain coordinate.

# %%
# Select some useful cols and print about contact emails 

cols = ['access', 'contact:email', 'contact:phone', 
        'addr:housenumber', 'addr:street'] #, 'addr:postcode' 'addr:country',
# Print only selected cols
schools[cols].head(10)
# Out:
#              access contact:email   contact:phone addr:housenumber addr:street
# 1839995160  private           NaN             NaN              NaN         NaN
# 1867872481      NaN           NaN             NaN              NaN         NaN
# 1921838442      NaN           NaN             NaN              NaN         NaN
# 2591601499      NaN           NaN             NaN              NaN         NaN
# 2591601502      NaN           NaN             NaN              NaN         NaN
# 2607957146      NaN           NaN  +7 495 6902162              NaN         NaN
# 2984341935      NaN           NaN  +7 962 9925132              NaN         NaN
# 3343744246      NaN           NaN             NaN              NaN         NaN
# 3343744267      NaN           NaN             NaN              NaN         NaN
# 3366397734      NaN           NaN             NaN              NaN         NaN

# %%
def school_info(name_city_distr): 
    ''' given city district get information about schools there
    phone or email, 
    availability of data 
    format of name_city_distr "Kamppi, Helsinki, Finland"
    
    name_city_distr must be a shapely Polygon or MultiPolygon. If you requested graph from place name or address, make sure your query resolves to a Polygon or MultiPolygon, and not some other geometry, like a Point. See OSMnx documentation for details.
    '''
    
    place_name = name_city_distr # e.g. "Kamppi, Helsinki, Finland"


    # Fetch OSM street network from the location
    graph = ox.graph_from_place(place_name)
    type(graph)

    print('loading graph of city')

    # Plot the streets
#    fig, ax = ox.plot_graph(graph)


    # Retrieve the footprint of our location
    area = ox.gdf_from_place(place_name)
    print('loading places')
    

    # Retrieve schools
    schools = ox.pois_from_place(place_name, amenities=['school'])

    # How many schools do we have in this district?
    len(schools)

    # Available columns and names of amenity we are searching for
    print(schools.columns)
    
    # not all places have the same columns!!!
    
    cols = ['access', #'contact:email', 'contact:phone', 
        'addr:housenumber', 'addr:street', 'education'] #, 'addr:postcode' 'addr:country',
    # Print only selected cols
    print(schools[cols].head(20))
    
def print_map_graph(place):
    
    place_name = name_city_distr # e.g. "Kamppi, Helsinki, Finland"


    # Fetch OSM street network from the location
    graph = ox.graph_from_place(place_name)
    type(graph)

    print('loading graph of city')

    # Plot the streets
    fig, ax = ox.plot_graph(graph)

    
    
def extract_network_city(place):
    '''extract network from city
    we use http://osm-traffic.com/ whichc allows direct download of graph data from OpenStreetMap in json format.
    '''
    print('extracting network from the city')

# %%
#call function 

print_map_graph("Innopolis, Russia")
# Out:
# loading graph of city
# loading places

# %%
print_map_graph("Kazan, Russia")
# Out:
# loading graph of city
# loading places

# %%
school_info("Kazan, Russia")
# Out:
# loading graph of city
# loading places
# Index(['access', 'addr:housenumber', 'addr:postcode', 'addr:street', 'amenity',
#        'barrier', 'bicycle', 'education', 'education_form:parttime',
#        'education_level:primary', 'education_profile:driving',
#        'education_profile:music', 'education_system:ru_standard',
#        'element_type', 'email', 'entrance', 'foot', 'geometry', 'horse',
#        'level', 'license_classes', 'man_made', 'motor_vehicle', 'name',
#        'name:en', 'name:ru', 'name:tt', 'opening_hours', 'osmid', 'phone',
#        'ref', 'surveillance', 'website', 'addr:city', 'addr:country',
#        'addr:suburb', 'building', 'building:colour', 'building:levels',
#        'fenced', 'full_name', 'government', 'int_name', 'language:ru',
#        'language:tt', 'nodes', 'official_name', 'old_name', 'operator',
#        'roof:shape', 'short_name', 'source', 'start_date',
#        'toilets:wheelchair', 'wheelchair', 'wikipedia', 'type', 'ways',
#        'wikidata', 'addr:place', 'contact:website'],
#       dtype='object')
#                 access addr:housenumber addr:street education
# 1049819501  permissive              NaN         NaN       NaN
# 1200411390         NaN              NaN         NaN       NaN
# 1201618072         NaN              NaN         NaN       NaN
# 1216071188         NaN              NaN         NaN       NaN
# 1242319762         NaN              NaN         NaN       NaN
# 1278068481         NaN              NaN         NaN       NaN
# 1327346501         NaN              NaN         NaN       NaN
# 1408855595         NaN              NaN         NaN       NaN
# 1408855605         NaN              NaN         NaN       NaN
# 1408855629         NaN              NaN         NaN       NaN
# 1460358708         NaN              NaN         NaN       NaN
# 1575273080         NaN              NaN         NaN       NaN
# 1588258805         NaN              NaN         NaN       NaN
# 1671735841         NaN              NaN         NaN       NaN
# 1671815395         NaN              NaN         NaN       NaN
# 1671815399         NaN              NaN         NaN       NaN
# 1671832071         NaN              NaN         NaN       NaN
# 1672063509         NaN              NaN         NaN       NaN
# 1672063563         NaN              NaN         NaN       NaN
# 1674858433         NaN              NaN         NaN       NaN

# %% [markdown]
# ### Plotting schools on a map
# Let us plot all schools in area of some city to see spatial distribution of schools.

# %%
import numpy as np
import matplotlib.pyplot as plt# Collect coords into list
coords = []


import requests
import json

#import data about Germany

overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["amenity"="school"](area);
 way["amenity"="school"](area);
 rel["amenity"="school"](area);
);
out center;
"""
response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data = response.json()

# %%
# plot data of amenities (e.g. schools or colleges)

for element in data['elements']:
  if element['type'] == 'node':
    lon = element['lon']
    lat = element['lat']
    coords.append((lon, lat))
  elif 'center' in element:
    lon = element['center']['lon']
    lat = element['center']['lat']
    coords.append((lon, lat))# Convert coordinates into numpy array
X = np.array(coords)
plt.plot(X[:, 0], X[:, 1], 'o')
plt.title('Schools in Germany')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.axis('equal')
plt.show()
